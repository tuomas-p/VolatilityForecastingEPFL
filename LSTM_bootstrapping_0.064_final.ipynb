# %% [markdown]
# ## LSTM (best bootstrapping implementation)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import arch.bootstrap as bootstrap
from numpy.random import RandomState
from tensorflow import keras
from tensorflow.keras.layers import Bidirectional, Dropout, Activation, Dense, LSTM
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
import sklearn.metrics as metrics
import tensorflow as tf
import os
import random
from keras import backend
# Out:
# 2023-05-31 11:52:36.240524: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-31 11:52:36.424820: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-31 11:52:36.424846: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-31 11:52:37.447363: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-31 11:52:37.447471: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-31 11:52:37.447484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# eliminate randomness for reproducability
seed_value = 42

# Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED'] = str(seed_value)

# Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# %%
# prepare data for LSTM train/test sets
df_ts = pd.read_csv("DF_TS.csv")
df_LSTM = df_ts[['daily_vol', 'mean_polarity_vader']]
upper_bound_vol = df_LSTM['daily_vol'].quantile(q=0.95)
df_LSTM['daily_vol'] = df_LSTM['daily_vol'].clip(0, upper_bound_vol)
df_LSTM['mean_polarity_vader'] = abs(df_LSTM['mean_polarity_vader'])
# Out:
# /tmp/ipykernel_99653/3143220735.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_LSTM['daily_vol'] = df_LSTM['daily_vol'].clip(0, upper_bound_vol)
# /tmp/ipykernel_99653/3143220735.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_LSTM['mean_polarity_vader'] = abs(df_LSTM['mean_polarity_vader'])

# %%
seq_len = 15

def split_into_sequences(data, seq_len):
    n_seq = len(data) - seq_len + 1
    return np.array([data[i:(i+seq_len)] for i in range(n_seq)])

def get_train_test_sets(data, seq_len, train_frac):
    sequences = split_into_sequences(data, seq_len)
    #print(sequences)
    n_train = int(sequences.shape[0] * train_frac)
    x_train = sequences[:n_train, :-1, :]
    y_train = sequences[:n_train, -1, 0]
    x_test = sequences[n_train:, :-1, :]
    y_test = sequences[n_train:, -1, 0]
    return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = get_train_test_sets(df_LSTM, seq_len, train_frac=0.9)

# %%
# fraction of the input to drop; helps prevent overfitting
dropout = 0.1
window_size = seq_len - 1

# build a multi-layer LSTM RNN
model = keras.Sequential()

model.add(
    LSTM(units=3, return_sequences=True, 
         input_shape=(x_train.shape[1], x_train.shape[-1]))
)

# Bidirectional allows for training of sequence data forwards and backwards
model.add(
    Bidirectional(LSTM(units=3, return_sequences=True))
)

model.add(Dropout(rate=dropout))

model.add(
    LSTM(units=4, return_sequences=True)
)

model.add(
    LSTM(units=2, return_sequences=True)
)

model.add(Dropout(rate=dropout))

model.add(
    LSTM(units=1, return_sequences=False)
)

# ReLU activation function as we will have a positive output
model.add(Activation('ReLU'))
# Out:
# 2023-05-31 11:52:39.509643: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-05-31 11:52:39.509677: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-31 11:52:39.509706: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tuomas-Lenovo): /proc/driver/nvidia/version does not exist
# 2023-05-31 11:52:39.509999: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
batch_size = 256

model.compile(
    loss='mean_squared_error',
    optimizer='adam'
)

history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=batch_size,
    shuffle=False,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 17s 2s/step - loss: 1.1480e-05 - val_loss: 5.6187e-06
# Epoch 2/20
# 3/3 [==============================] - 0s 56ms/step - loss: 6.8950e-06 - val_loss: 5.8597e-06
# Epoch 3/20
# 3/3 [==============================] - 0s 55ms/step - loss: 6.4505e-06 - val_loss: 3.4031e-06
# Epoch 4/20
# 3/3 [==============================] - 0s 55ms/step - loss: 8.1350e-06 - val_loss: 2.9678e-06
# Epoch 5/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.5556e-06 - val_loss: 5.2900e-06
# Epoch 6/20
# 3/3 [==============================] - 0s 58ms/step - loss: 6.2738e-06 - val_loss: 3.7062e-06
# Epoch 7/20
# 3/3 [==============================] - 0s 56ms/step - loss: 6.0104e-06 - val_loss: 2.9201e-06
# Epoch 8/20
# 3/3 [==============================] - 0s 54ms/step - loss: 6.1921e-06 - val_loss: 2.9819e-06
# Epoch 9/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.3970e-06 - val_loss: 3.9481e-06
# Epoch 10/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.4189e-06 - val_loss: 3.3128e-06
# Epoch 11/20
# 3/3 [==============================] - 0s 58ms/step - loss: 5.5873e-06 - val_loss: 2.8374e-06
# Epoch 12/20
# 3/3 [==============================] - 0s 60ms/step - loss: 5.7418e-06 - val_loss: 3.0093e-06
# Epoch 13/20
# 3/3 [==============================] - 0s 62ms/step - loss: 5.4238e-06 - val_loss: 3.4514e-06
# Epoch 14/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.3306e-06 - val_loss: 2.9878e-06
# Epoch 15/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.3002e-06 - val_loss: 2.7938e-06
# Epoch 16/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.4018e-06 - val_loss: 2.9513e-06
# Epoch 17/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.0704e-06 - val_loss: 3.1833e-06
# Epoch 18/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.1414e-06 - val_loss: 2.8473e-06
# Epoch 19/20
# 3/3 [==============================] - 0s 56ms/step - loss: 5.3196e-06 - val_loss: 2.7626e-06
# Epoch 20/20
# 3/3 [==============================] - 0s 66ms/step - loss: 5.2521e-06 - val_loss: 2.9473e-06

# %%
y_pred = model.predict(x_test)
# plots of prediction against actual data
plt.plot(y_test, label='Actual Volatility', color='orange')
plt.plot(y_pred, label='Predicted Volatility', color='green')
 
plt.title('Tesla Volatility Prediction')
plt.xlabel('Days')
plt.ylabel('Volatility')
plt.legend(loc='best')

plt.show()
# Out:
# 3/3 [==============================] - 3s 11ms/step

# %%
rsquared_oos_lstm = metrics.r2_score(y_test, y_pred)
print("The out-of-sample R^2 for LSTM is: {:.4f}".format(rsquared_oos_lstm))
# Out:
# The out-of-sample R^2 for LSTM is: 0.0215

# %%
y_pred_train = model.predict(x_train)

# plots of prediction against actual data
plt.plot(y_train, label='Actual Vol', color='orange')
plt.plot(y_pred_train, label='Predicted Vol', color='green')
 
plt.title('Tesla Volatility Prediction')
plt.xlabel('Days')
plt.ylabel('Volatility')
plt.legend(loc='best')

plt.show();
# Out:
# 23/23 [==============================] - 0s 8ms/step

# %% [markdown]
# ## Using bootstrapping

# %%
# for reproducibility
rs = RandomState(1)
opti_len = bootstrap.optimal_block_length(df_LSTM)
# we use the optimal length for the volatility
bs = bootstrap.StationaryBootstrap(opti_len['stationary'].iloc[0], df_LSTM, random_state=rs)

bootstrapping_length = 9
y_avg = y_pred / (1 + bootstrapping_length)
y_train_pred_avg = y_pred_train / (1 + bootstrapping_length)
for data in bs.bootstrap(bootstrapping_length):
    temp_df = data[0][0]
    x_train_temp, y_train_temp, x_test_temp, y_test_temp = get_train_test_sets(temp_df, seq_len, train_frac=0.9)
    # model.fit 
    history = model.fit(
        x_train_temp,
        y_train_temp,
        epochs=20,
        batch_size=batch_size,
        shuffle=False,
        validation_split=0.2
    )
    # use the original test set, last fraction of the samples to test the model
    y_pred_temp = model.predict(x_test)
    y_pred_train = model.predict(x_train)
    y_avg += y_pred_temp / (1 + bootstrapping_length)
    y_train_pred_avg += y_pred_train / (1 + bootstrapping_length)
# Out:
# Epoch 1/20
# 1/3 [=========>....................] - ETA: 0s - loss: 5.8259e-06
# /home/tuomasp/anaconda3/lib/python3.9/site-packages/arch/bootstrap/base.py:414: FutureWarning: random_state is deprecated and will be removed in a future version. The default random number generator is changing to a NumPy Generator. To continue using RandomState, please directly pass a RandomState instance using the ``generator`` keyword argument.
#   warnings.warn(
# 3/3 [==============================] - 0s 81ms/step - loss: 5.8117e-06 - val_loss: 2.9586e-06
# Epoch 2/20
# 3/3 [==============================] - 0s 53ms/step - loss: 5.5621e-06 - val_loss: 2.9426e-06
# Epoch 3/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.7639e-06 - val_loss: 3.0327e-06
# Epoch 4/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.6372e-06 - val_loss: 3.0826e-06
# Epoch 5/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.8944e-06 - val_loss: 2.9363e-06
# Epoch 6/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.6599e-06 - val_loss: 2.8882e-06
# Epoch 7/20
# 3/3 [==============================] - 0s 56ms/step - loss: 5.7111e-06 - val_loss: 2.9509e-06
# Epoch 8/20
# 3/3 [==============================] - 0s 56ms/step - loss: 5.5420e-06 - val_loss: 2.9404e-06
# Epoch 9/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.5620e-06 - val_loss: 2.9306e-06
# Epoch 10/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.7108e-06 - val_loss: 2.9287e-06
# Epoch 11/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.6719e-06 - val_loss: 2.9226e-06
# Epoch 12/20
# 3/3 [==============================] - 0s 53ms/step - loss: 5.6889e-06 - val_loss: 2.9057e-06
# Epoch 13/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.5424e-06 - val_loss: 2.8575e-06
# Epoch 14/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.5252e-06 - val_loss: 2.8574e-06
# Epoch 15/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.4399e-06 - val_loss: 2.8809e-06
# Epoch 16/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.4594e-06 - val_loss: 2.8673e-06
# Epoch 17/20
# 3/3 [==============================] - 0s 54ms/step - loss: 5.5708e-06 - val_loss: 2.8325e-06
# Epoch 18/20
# 3/3 [==============================] - 0s 53ms/step - loss: 5.5847e-06 - val_loss: 2.8454e-06
# Epoch 19/20
# 3/3 [==============================] - 0s 55ms/step - loss: 5.5891e-06 - val_loss: 2.8483e-06
# Epoch 20/20
# 3/3 [==============================] - 0s 57ms/step - loss: 5.5016e-06 - val_loss: 2.8245e-06
# 3/3 [==============================] - 0s 8ms/step
# 23/23 [==============================] - 0s 8ms/step
# Epoch 1/20
# 3/3 [==============================] - 0s 77ms/step - loss: 3.3172e-06 - val_loss: 3.3789e-06
# Epoch 2/20
# 3/3 [==============================] - 0s 53ms/step - loss: 3.5947e-06 - val_loss: 3.1215e-06
# Epoch 3/20
# 3/3 [==============================] - 0s 57ms/step - loss: 3.7176e-06 - val_loss: 3.4349e-06
# Epoch 4/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.3803e-06 - val_loss: 3.5898e-06
# Epoch 5/20
# 3/3 [==============================] - 0s 57ms/step - loss: 3.2499e-06 - val_loss: 3.2453e-06
# Epoch 6/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.5434e-06 - val_loss: 3.2149e-06
# Epoch 7/20
# 3/3 [==============================] - 0s 53ms/step - loss: 3.4860e-06 - val_loss: 3.4175e-06
# Epoch 8/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.3276e-06 - val_loss: 3.4300e-06
# Epoch 9/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.3015e-06 - val_loss: 3.2673e-06
# Epoch 10/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.3373e-06 - val_loss: 3.2418e-06
# Epoch 11/20
# 3/3 [==============================] - 0s 53ms/step - loss: 3.3597e-06 - val_loss: 3.3729e-06
# Epoch 12/20
# 3/3 [==============================] - 0s 55ms/step - loss: 3.3068e-06 - val_loss: 3.3031e-06
# Epoch 13/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.3435e-06 - val_loss: 3.2091e-06
# Epoch 14/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.3442e-06 - val_loss: 3.3090e-06
# Epoch 15/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.2769e-06 - val_loss: 3.3336e-06
# Epoch 16/20
# 3/3 [==============================] - 0s 53ms/step - loss: 3.1954e-06 - val_loss: 3.2613e-06
# Epoch 17/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.1938e-06 - val_loss: 3.2912e-06
# Epoch 18/20
# 3/3 [==============================] - 0s 53ms/step - loss: 3.2062e-06 - val_loss: 3.2663e-06
# Epoch 19/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.2369e-06 - val_loss: 3.2310e-06
# Epoch 20/20
# 3/3 [==============================] - 0s 55ms/step - loss: 3.2444e-06 - val_loss: 3.3054e-06
# 3/3 [==============================] - 0s 8ms/step
# 23/23 [==============================] - 0s 7ms/step
# Epoch 1/20
# 3/3 [==============================] - 0s 81ms/step - loss: 3.8452e-06 - val_loss: 3.4368e-06
# Epoch 2/20
# 3/3 [==============================] - 0s 56ms/step - loss: 4.1382e-06 - val_loss: 3.6809e-06
# Epoch 3/20
# 3/3 [==============================] - 0s 54ms/step - loss: 4.4544e-06 - val_loss: 3.3564e-06
# Epoch 4/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3.9416e-06 - val_loss: 3.3518e-06
# Epoch 5/20
# 3/3 [==============================] - 0s 53ms/step - loss: 3.8475e-06 - val_loss: 3.4901e-06
# Epoch 6/20
# 3/3 [==============================] - 0s 53ms/step - loss: 4.2211e-06 - val_loss: 3.3940e-06
# Epoch 7/20
# 3/3 [==============================] - 0s 55ms/step - loss: 4.0778e-06 - val_loss: 3.3330e-06
# Epoch 8/20
# 3/3 [==============================] - 0s 54ms/step - loss: 3
-06
# Epoch 20/20
# 3/3 [==============================] - 0s 55ms/step - loss: 3.9397e-06 - val_loss: 3.7875e-06
# 3/3 [==============================] - 0s 9ms/step
# 23/23 [==============================] - 0s 8ms/step
# Epoch 1/20
# 3/3 [==============================] - 0s 79ms/step - loss: 4.6284e-06 - val_loss: 2.7858e-06
# Epoch 2/20
# 3/3 [==============================] - 0s 57ms/step - loss: 4.5933e-06 - val_loss: 2.7217e-06
# Epoch 3/20
# 3/3 [==============================] - 0s 55ms/step - loss: 4.5956e-06 - val_loss: 2.7180e-06
# Epoch 4/20
# 3/3 [==============================] - 0s 57ms/step - loss: 4.6038e-06 - val_loss: 2.7713e-06
# Epoch 5/20
# 3/3 [==============================] - 0s 56ms/step - loss: 4.5781e-06 - val_loss: 2.7278e-06
# Epoch 6/20
# 3/3 [==============================] - 0s 55ms/step - loss: 4.5763e-06 - val_loss: 2.7356e-06
# Epoch 7/20
# 3/3 [==============================] - 0s 56ms/step - loss: 4.5614e-06 - val_loss: 2.7614e-06
# Epoch 8/20
# 3/3 [==============================] - 0s 57ms/step - loss: 4.5395e-06 - val_loss: 2.7266e-06
# Epoch 9/20
# 3/3 [==============================] - 0s 53ms/step - loss: 4.6467e-06 - val_loss: 2.7372e-06
# Epoch 10/20
# 3/3 [==============================] - 0s 56ms/step - loss: 4.5566e-06 - val_loss: 2.7681e-06
# Epoch 11/20
# 3/3 [==============================] - 0s 55ms/step - loss: 4.5884e-06 - val_loss: 2.7364e-06
# Epoch 12/20
# 3/3 [==============================] - 0s 55ms/step - loss: 4.6059e-06 - val_loss: 2.7242e-06
# Epoch 13/20
# 3/3 [==============================] - 0s 56ms/step - loss: 4.5469e-06 - val_loss: 2.7440e-06
# Epoch 14/20
# 3/3 [==============================] - 0s 55ms/step - loss: 4.5711e-06 - val_loss: 2.7398e-06
# Epoch 15/20
# 3/3 [==============================] - 0s 53ms/step - loss: 4.5650e-06 - val_loss: 2.7327e-06
# Epoch 16/20
# 3/3 [==============================] - 0s 55ms/step - loss: 4.5516e-06 - val_loss: 2.7455e-06
# Epoch 17/20
# 3/3 [==============================] - 0s 53ms/step - loss: 4.5286e-06 - val_loss: 2.7458e-06
# Epoch 18/20
# 3/3 [==============================] - 0s 53ms/step - loss: 4.5823e-06 - val_loss: 2.7339e-06
# Epoch 19/20
# 3/3 [==============================] - 0s 53ms/step - loss: 4.5839e-06 - val_loss: 2.7329e-06
# Epoch 20/20
# 3/3 [==============================] - 0s 57ms/step - loss: 4.5635e-06 - val_loss: 2.7625e-06
# 3/3 [==============================] - 0s 8ms/step
# 23/23 [==============================] - 0s 8ms/step

# %%
# plots of prediction against actual data
plt.plot(y_test, label='Actual Volatility', color='orange')
plt.plot(y_avg, label='Predicted Volatility', color='green')

plt.title('Tesla Volatility Prediction')
plt.xlabel('Days')
plt.ylabel('Volatility')
plt.legend(loc='best')

plt.show()

# %%
rsquared_oos_lstm_b = metrics.r2_score(y_test, y_avg)
print("The out-of-sample R^2 for LSTM, with bootstrapping, is: {:.4f}".format(rsquared_oos_lstm_b))
# Out:
# The out-of-sample R^2 for LSTM, with bootstrapping, is: 0.0641

# %%
plt.plot(y_train, label='Actual Vol', color='orange')
plt.plot(y_train_pred_avg, label='Predicted Vol', color='green')
 
plt.title('Tesla Volatility Prediction')
plt.xlabel('Days')
plt.ylabel('Volatility')
plt.legend(loc='best')

plt.show()

# %%
rsquared_is_lstm = metrics.r2_score(y_train, y_train_pred_avg)
print("The in-sample R^2 for LSTM is: {:.4f}".format(rsquared_is_lstm))
# Out:
# The in-sample R^2 for LSTM is: -0.0029
